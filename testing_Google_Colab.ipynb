# %% [markdown]
# <a href="https://colab.research.google.com/github/curtiscu/LYIT/blob/master/testing_Google_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %%
import numpy as np
import scipy

# %%
import cython

# %%
# !pip install mido
# Out:
# ...
#      |████████████████████████████████| 61kB 1.1MB/s
# ...

# %%
# !pip install pytest
# !pip install pyaudio

# %%
# !pip install pyfftw
# Out:
# ...
#      |████████████████████████████████| 2.6MB 1.4MB/s
# ...

# %%
# !pip install madmom
# Out:
# ...
#      |████████████████████████████████| 20.0MB 44.2MB/s
# ...
#   Created wheel for madmom: filename=madmom-0.16.1-cp36-cp36m-linux_x86_64.whl size=20955192 sha256=c803dfa36b50a7e7f677c8d31e49a236b67e802395c3877ee03fe2c9b344aebc
#   Stored in directory: /root/.cache/pip/wheels/21/0c/30/e0141aa75fb0a829ba5e1dca2be0860dc98502c1789616637d
# Successfully built madmom
# ...

# %%
# !pip install tensorflow==1.15
# Out:
# ...
#      |████████████████████████████████| 412.3MB 39kB/s
# ...
#      |████████████████████████████████| 3.8MB 41.3MB/s
# ...
#      |████████████████████████████████| 512kB 43.4MB/s
# ...
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7540 sha256=a89f87c8ec971c7a691090f30cbf3212fd5eda9a49d96e98e004798198bd8ec0
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# ...
#   Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
#   Found existing installation: tensorboard 2.1.1
#     Uninstalling tensorboard-2.1.1:
#       Successfully uninstalled tensorboard-2.1.1
#   Found existing installation: tensorflow-estimator 2.2.0rc0
#     Uninstalling tensorflow-estimator-2.2.0rc0:
#       Successfully uninstalled tensorflow-estimator-2.2.0rc0
#   Found existing installation: tensorflow 2.2.0rc1
#     Uninstalling tensorflow-2.2.0rc1:
# ...

# %%
# %tensorflow_version 1.15
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.15`. This will be interpreted as: `1.x`.
#
#
# TensorFlow 1.x selected.

# %%
# test the install 
import tensorflow as tf
print(tf.__version__)
print(tf.reduce_sum(tf.random.normal([1000, 1000])))
# Out:
# 1.15.2
# Tensor("Sum:0", shape=(), dtype=float32)

# %%
# !pip install fpdf
# Out:
# ...
#   Created wheel for fpdf: filename=fpdf-1.7.2-py2.py3-none-any.whl size=40720 sha256=ae6927b5fbe22f285e746549d6ecf7a96467d61bb4a580b92635a688a05035bd
#   Stored in directory: /root/.cache/pip/wheels/9a/e9/77/4554ff5c99bc3f487c8d69620d8c41d99d54e9c54ab20ef4c9
# Successfully built fpdf
# ...

# %%
# !pip install ADTLib
# Out:
# ...
#      |████████████████████████████████| 8.0MB 1.4MB/s
# ...
#   Using cached https://files.pythonhosted.org/packages/20/0a/81beb587b1ae832ea6a1901dc7c6faa380e8dd154e0a862f0a9f3d2afab9/mido-1.2.9-py2.py3-none-any.whl
# ...
#   Created wheel for ADTLib: filename=ADTLib-2.1.2-cp36-none-any.whl size=8035733 sha256=88e852244d694dd36abb4a7ab1bf7d5a5aa41e301aa54966d4a907431cacbede
#   Stored in directory: /root/.cache/pip/wheels/6b/e8/04/a57153ac4bdd172ac5e91a37ec54244e268f528e2c2196d1cb
# Successfully built ADTLib
# ERROR: magenta 0.3.19 has requirement mido==1.2.6, but you'll have mido 1.2.9 which is incompatible.
# ...
#   Found existing installation: mido 1.2.6
#     Uninstalling mido-1.2.6:
#       Successfully uninstalled mido-1.2.6
# ...

# %%
import matplotlib.pyplot as plt, librosa, IPython.display as ipd

# %%
from ADTLib import ADT

# %%
filename = './Rosanna_short.wav'
file_EAD1 = './EAD_test1.mp3'
x, sr = librosa.load(file_EAD1)

# %%
ipd.Audio(x, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
adt_stuff = ADT([file_EAD1])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/ADTLib/utils/__init__.py:289: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/ADTLib/utils/__init__.py:271: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/ADTLib/utils/__init__.py:291: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/ADTLib/utils/__init__.py:251: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/ADTLib/utils/__init__.py:259: LSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# ...

# %%
adt_stuff
# Out:
# [{'Hihat': array([ 0.09287982,  0.19736961,  0.32507937,  0.56888889,  0.85913832,
#           1.13777778,  1.40480726,  1.67183673,  1.95047619,  2.22911565,
#           2.49614512,  2.7631746 ,  3.04181406,  3.33206349,  3.58748299,
#           3.86612245,  4.12154195,  4.42340136,  4.53950113,  4.67882086,
#           4.95746032,  5.2244898 ,  5.50312925,  5.77015873,  6.06040816,
#           6.31582766,  6.61768707,  6.87310658,  7.15174603,  7.41877551,
#           7.68580499,  7.92961451,  8.20825397,  8.52172336,  8.78875283,
#           9.29959184,  9.61306122,  9.85687075, 10.1355102 , 10.40253968,
#          10.68117914, 10.99464853, 11.13396825, 11.25006803, 11.54031746,
#          11.65641723, 11.79573696, 12.07437642, 12.20208617, 12.3414059 ,
#          12.62004535, 12.75936508, 12.88707483, 13.16571429, 13.29342404,
#          13.42113379, 13.71138322, 13.83909297, 13.9784127 , 14.24544218,
#          14.3847619 , 14.50086168, 14.80272109, 14.93043084, 15.04653061,
# ...

# %%
drum_onsets = adt_stuff[0]
drum_onsets
# Out:
# {'Hihat': array([ 0.09287982,  0.19736961,  0.32507937,  0.56888889,  0.85913832,
#          1.13777778,  1.40480726,  1.67183673,  1.95047619,  2.22911565,
#          2.49614512,  2.7631746 ,  3.04181406,  3.33206349,  3.58748299,
#          3.86612245,  4.12154195,  4.42340136,  4.53950113,  4.67882086,
#          4.95746032,  5.2244898 ,  5.50312925,  5.77015873,  6.06040816,
#          6.31582766,  6.61768707,  6.87310658,  7.15174603,  7.41877551,
#          7.68580499,  7.92961451,  8.20825397,  8.52172336,  8.78875283,
#          9.29959184,  9.61306122,  9.85687075, 10.1355102 , 10.40253968,
#         10.68117914, 10.99464853, 11.13396825, 11.25006803, 11.54031746,
#         11.65641723, 11.79573696, 12.07437642, 12.20208617, 12.3414059 ,
#         12.62004535, 12.75936508, 12.88707483, 13.16571429, 13.29342404,
#         13.42113379, 13.71138322, 13.83909297, 13.9784127 , 14.24544218,
#         14.3847619 , 14.50086168, 14.80272109, 14.93043084, 15.04653061,
# ...

# %%
keys = drum_onsets.keys()
keys
# Out:
# dict_keys(['Kick', 'Snare', 'Hihat'])

# %%
for instrument in keys:
  print('{} : {} '.format(instrument, drum_onsets[instrument]))
# Out:
# Kick : [ 0.32507937  1.40480726  2.49614512  3.58748299  4.66721088  5.77015873
#   6.88471655  7.91800454  9.05578231 10.1355102  11.25006803 12.32979592
#  13.40952381 14.4892517  15.84761905 16.96217687 17.77487528]
# Snare : [ 0.08126984  0.84752834  1.96208617  3.04181406  4.12154195  4.41179138
#   4.52789116  5.2244898   6.31582766  7.41877551  8.20825397  8.52172336
#   8.77714286  9.61306122 10.68117914 11.78412698 12.88707483 13.96680272
#  15.04653061 16.40489796 17.22920635 17.3569161 ]
# Hihat : [ 0.09287982  0.19736961  0.32507937  0.56888889  0.85913832  1.13777778
#   1.40480726  1.67183673  1.95047619  2.22911565  2.49614512  2.7631746
#   3.04181406  3.33206349  3.58748299  3.86612245  4.12154195  4.42340136
#   4.53950113  4.67882086  4.95746032  5.2244898   5.50312925  5.77015873
#   6.06040816  6.31582766  6.61768707  6.87310658  7.15174603  7.41877551
#   7.68580499  7.92961451  8.20825397  8.52172336  8.78875283  9.29959184
# ...

# %%
ipd.Image('./file_EAD1_drumtab.png')
